# %%
# Célula 1
consumo_diario = [
    50, 45, 55, 60, 48, 52, 47, 49, 53, 
    51, 56, 46, 54, 61, 49, 53, 48, 50, 52, 
    47, 56, 50, 55, 60, 48, 52, 47, 49, 53, 51 
]

# Célula 2
def consumo(lista):
    # Implemente aqui
    if len(lista) == 0:
        return 0.0
    return sum(lista) / len(lista)

# Célula 3 (teste)
print(f"O consumo diário médio foi: {consumo(consumo_diario)}")
# Out:
# O consumo diário médio foi: 51.56666666666667

# %%
# Célula 1
consumo_diario = [
    50, 45, 55, 60, 48, 52, 47, 49, 53, 
    51, 56, 46, 54, 61, 49, 53, 48, 50, 52, 
    47, 56, 50, 55, 60, 48, 52, 47, 49, 53, 51 
]

# %%
# Célula 2
def consumo(lista):
    # Implemente aqui
    if len(lista) == 0:
        return 0.0
    return sum(lista) / len(lista)

# %%
# Célula 3 (teste)
print(f"O consumo diário médio foi: {consumo(consumo_diario)}")
# Out:
# O consumo diário médio foi: 51.56666666666667
